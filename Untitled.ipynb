# %%
import pandas as pd
df = pd.read_csv("Maths.csv")
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("Maths.csv")
#       3 df
#
# File /lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd
df = pd.read_csv("Maths.csv")
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("Maths.csv")
#       3 df
#
# File /lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd
df = pd.read_csv("bank-additional-full.csv")
df
# Out:
#       age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# 0      56;"housemaid";"married";"basic.4y";"no";"no";...
# 1      57;"services";"married";"high.school";"unknown...
# 2      37;"services";"married";"high.school";"no";"ye...
# 3      40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4      56;"services";"married";"high.school";"no";"no...
# ...                                                  ...
# 41183  73;"retired";"married";"professional.course";"...
# 41184  46;"blue-collar";"married";"professional.cours...
# 41185  56;"retired";"married";"university.degree";"no...
# 41186  44;"technician";"married";"professional.course...
# 41187  74;"retired";"married";"professional.course";"...
#
# [41188 rows x 1 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of       age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# 0      56;"housemaid";"married";"basic.4y";"no";"no";...
# 1      57;"services";"married";"high.school";"unknown...
# 2      37;"services";"married";"high.school";"no";"ye...
# 3      40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4      56;"services";"married";"high.school";"no";"no...
# ...                                                  ...
# 41183  73;"retired";"married";"professional.course";"...
# 41184  46;"blue-collar";"married";"professional.cours...
# 41185  56;"retired";"married";"university.degree";"no...
# 41186  44;"technician";"married";"professional.course...
# 41187  74;"retired";"married";"professional.course";"...
#
# [41188 rows x 1 columns]>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# 0      56;"housemaid";"married";"basic.4y";"no";"no";...
# 1      57;"services";"married";"high.school";"unknown...
# 2      37;"services";"married";"high.school";"no";"ye...
# 3      40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4      56;"services";"married";"high.school";"no";"no...
# ...                                                  ...
# 41183  73;"retired";"married";"professional.course";"...
# 41184  46;"blue-collar";"married";"professional.cours...
# 41185  56;"retired";"married";"university.degree";"no...
# 41186  44;"technician";"married";"professional.course...
# 41187  74;"retired";"married";"professional.course";"...
#
# [41188 rows x 1 columns]>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=41188, step=1)

# %%
df.coloumn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-cfbd978eed9b> in ?()
# ----> 1 df.coloumn
#
# /lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'coloumn'

# %%
df.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1031965220f7> in ?()
# ----> 1 df.column
#
# /lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df.columns.values
# Out:
# array(['age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"'], dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# 0      56;"housemaid";"married";"basic.4y";"no";"no";...
# 1      57;"services";"married";"high.school";"unknown...
# 2      37;"services";"married";"high.school";"no";"ye...
# 3      40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4      56;"services";"married";"high.school";"no";"no...
# ...                                                  ...
# 41183  73;"retired";"married";"professional.course";"...
# 41184  46;"blue-collar";"married";"professional.cours...
# 41185  56;"retired";"married";"university.degree";"no...
# 41186  44;"technician";"married";"professional.course...
# 41187  74;"retired";"married";"professional.course";"...
#
# [41188 rows x 1 columns]>

# %%
df.column.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-a82db8389fc7> in ?()
# ----> 1 df.column.name
#
# /lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df.columns.name

# %%
df.columns.names
# Out:
# FrozenList([None])

# %%
df.dtypes
# Out:
# age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"    object
# dtype: object

# %%
df.shape
# Out:
# (41188, 1)

# %%
df.iloc[100]
# Out:
# age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"    54;"services";"married";"unknown";"no";"yes";"...
# Name: 100, dtype: object
