# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Administrator/OneDrive/Desktop/student_perform.csv")

# %%
df
# Out:
#     maths_score  reading_score  writing_score  placement  club_join_year  \
# 0            77             81           73.0       85.0            2018
# 1            64             81           64.0       81.0            2012
# 2            67             82           63.0       86.0            2016
# 3            68             86           64.0       83.0            2012
# 4            64             83           65.0       89.0            2011
# 5            65             65           67.0       97.0            2016
# 6            66             76           74.0      100.0            2010
# 7            73             80           77.0       97.0            2012
# 8            67             88           67.0       89.0            2010
# 9            95             87           80.0       99.0            2016
# 10           75             83           65.0       85.0            2024
# 11           68             79            NaN       88.0            2015
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   maths_score            30 non-null     int64
#  1   reading_score          30 non-null     int64
#  2   writing_score          29 non-null     float64
#  3   placement              29 non-null     float64
#  4   club_join_year         30 non-null     int64
#  5   placement_offer_count  30 non-null     int64
# dtypes: float64(2), int64(4)
# memory usage: 1.5 KB

# %%
df.describe()
# Out:
#        maths_score  reading_score  writing_score   placement  club_join_year  \
# count    30.000000      30.000000      29.000000   29.000000       30.000000
# mean     69.733333      81.366667      70.413793   91.068966     2015.433333
# std       6.957672       5.020533       5.415040    6.953576        4.739295
# min      61.000000      65.000000      62.000000   80.000000     2010.000000
# 25%      65.250000      80.000000      65.000000   85.000000     2011.000000
# 50%      67.000000      81.500000      71.000000   89.000000     2015.000000
# 75%      74.750000      84.750000      74.000000   98.000000     2018.750000
# max      95.000000      88.000000      80.000000  100.000000     2024.000000
#
#        placement_offer_count
# count              30.000000
# mean                2.800000
# std                 0.406838
# min                 2.000000
# 25%                 3.000000
# 50%                 3.000000
# 75%                 3.000000
# max                 3.000000

# %%
df.writing_score.fillna(65)
# Out:
# 0     73.0
# 1     64.0
# 2     63.0
# 3     64.0
# 4     65.0
# 5     67.0
# 6     74.0
# 7     77.0
# 8     67.0
# 9     80.0
# 10    65.0
# 11    65.0
# 12    63.0
# 13    75.0
# 14    72.0
# 15    74.0
# 16    73.0
# 17    71.0
# 18    68.0
# 19    62.0
# 20    79.0
# 21    76.0
# 22    67.0
# 23    73.0
# 24    71.0
# 25    76.0
# 26    67.0
# 27    65.0
# 28    72.0
# 29    79.0
# Name: writing_score, dtype: float64
